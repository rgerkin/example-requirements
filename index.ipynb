# %% [markdown]
# # ASU Math Club Python Workshop
# ## Working with *Jupyter* Notebooks
# ### Presented by **Rick Gerkin** 2/24/17

# %% [markdown]
# ## Import modules and setup inline plotting environment

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /home/main/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# ## Some example functions

# %%
from numpy import random
from scipy.ndimage.filters import gaussian_filter

# %% [markdown]
# ## Make some plots!

# %%
x = random.randn(10,500)
x = gaussian_filter(x, [0, 10])
sns.tsplot(x, err_style='unit_traces');

# %%
mat = random.randn(10,20)
sns.heatmap(mat);

# %% [markdown]
# ### How about some equations?

# %% [markdown]
# $x^2 + \alpha$

# %% [markdown]
# ### Or some links to keep us <a href="https://www.youtube.com/watch?v=dQw4w9WgXcQ">rolling</a>!

# %%
pd.DataFrame(np.random.rand(60,5),
             index=range(1950,2010),
             columns=['Alice','Bob','Carl','Donna','Egbert'])
# Out:
#          Alice       Bob      Carl     Donna    Egbert
# 1950  0.836280  0.778505  0.086493  0.398679  0.592948
# 1951  0.766047  0.683075  0.191709  0.009019  0.778947
# 1952  0.450701  0.475438  0.220109  0.827525  0.375704
# 1953  0.755866  0.961525  0.741850  0.562097  0.652967
# 1954  0.289878  0.710368  0.975726  0.641090  0.508403
# 1955  0.595934  0.461140  0.525998  0.860575  0.052589
# 1956  0.293108  0.378072  0.676764  0.198454  0.569675
# 1957  0.080187  0.607677  0.353990  0.905637  0.667429
# 1958  0.590245  0.052062  0.745565  0.479112  0.781167
# 1959  0.886622  0.217754  0.803624  0.925839  0.269037
# 1960  0.556486  0.020066  0.595322  0.999273  0.955020
# 1961  0.512342  0.659946  0.052197  0.421605  0.458287
# 1962  0.767141  0.500418  0.205425  0.670159  0.182566
# 1963  0.170695  0.322680  0.527051  0.340463  0.791961
# 1964  0.151845  0.755879  0.346694  0.871271  0.417346
# 1965  0.086576  0.542968  0.653149  0.237141  0.386119
# 1966  0.204155  0.542957  0.129796  0.699439  0.296048
# 1967  0.247406  0.957533  0.008937  0.538647  0.753014
# 1968  0.542008  0.244829  0.015253  0.910413  0.934498
# 1969  0.047793  0.626433  0.009157  0.201205  0.903916
# 1970  0.328650  0.836632  0.458313  0.257869  0.299901
# 1971  0.092063  0.578386  0.547315  0.580010  0.213071
# 1972  0.695441  0.722597  0.752681  0.609701  0.434043
# 1973  0.997590  0.567082  0.464810  0.358451  0.962803
# 1974  0.651640  0.855807  0.742225  0.793196  0.230589
# 1975  0.767535  0.716813  0.389752  0.284083  0.600516
# 1976  0.347531  0.121361  0.638786  0.205404  0.457945
# 1977  0.329055  0.655655  0.981153  0.716551  0.617107
# 1978  0.974685  0.237372  0.092458  0.179096  0.206713
# 1979  0.412038  0.375636  0.578188  0.231469  0.276819
# 1980  0.101235  0.157473  0.603549  0.788414  0.263383
# 1981  0.886422  0.282148  0.050125  0.607339  0.507595
# 1982  0.196125  0.121106  0.257017  0.606652  0.886106
# 1983  0.725804  0.659496  0.590046  0.842275  0.261885
# 1984  0.099912  0.959177  0.426702  0.724890  0.822186
# 1985  0.454119  0.297253  0.668982  0.463668  0.329073
# 1986  0.939838  0.632414  0.057987  0.148513  0.177188
# 1987  0.042864  0.025888  0.354559  0.812010  0.643402
# 1988  0.434624  0.183626  0.114233  0.624853  0.011908
# 1989  0.999365  0.597973  0.381147  0.910053  0.717250
# 1990  0.796437  0.182057  0.368627  0.871375  0.223193
# 1991  0.973551  0.672267  0.324949  0.830439  0.927583
# 1992  0.896506  0.969583  0.828287  0.971829  0.458599
# 1993  0.786884  0.925930  0.974541  0.975188  0.821266
# 1994  0.596455  0.301967  0.092725  0.553449  0.965035
# 1995  0.481133  0.010961  0.252995  0.212324  0.301267
# 1996  0.964555  0.735935  0.445978  0.527681  0.927294
# 1997  0.663805  0.937569  0.164880  0.306129  0.661714
# 1998  0.829959  0.760983  0.155156  0.056216  0.623301
# 1999  0.037336  0.347682  0.742080  0.094848  0.346984
# 2000  0.059413  0.327667  0.990782  0.043935  0.578766
# 2001  0.020114  0.755759  0.714603  0.648349  0.598175
# 2002  0.384356  0.244061  0.083705  0.510591  0.444910
# 2003  0.825910  0.383845  0.510698  0.101637  0.262464
# 2004  0.289234  0.811562  0.250560  0.125811  0.158065
# 2005  0.104706  0.341199  0.551367  0.204079  0.756200
# 2006  0.731188  0.633563  0.130325  0.539409  0.794950
# 2007  0.456774  0.234011  0.566250  0.251421  0.934385
# 2008  0.866165  0.205445  0.468412  0.023052  0.882303
# 2009  0.074463  0.197323  0.803199  0.937002  0.465167

# %%
from IPython.display import Javascript,display

# %% [markdown]
# ### Who remembers the &lt;hr&gt; tag?
# <hr>

# %% [markdown]
# ### The Jupyter notebook is a fully functional web scripting engine.

# %%
Javascript("alert('hello')")

# %% [markdown]
# ### Let's make the table above a bit nicer

# %%
prefix = "//ajax.aspnetcdn.com/ajax/jquery.dataTables/1.9.0"
js = Javascript("$('table').dataTable();",
    lib=["%s/jquery.dataTables.min.js" % prefix],
    css=["%s/css/jquery.dataTables.css" % prefix])
display(js)
